# %% [markdown]
# # Assession Dimension Schema
# Objective: Investigate csv files for station and state. Clean files as needed. Determine appropriate schema to use in Redshift.

# %%
# !ls ../data/raw/dimension
# Out:
# hpd_states.txt	HPD_v02r02_stationinv_c20221129.csv

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://')

# %% [markdown]
# ## Station

# %%
df_st = pd.read_csv('../data/raw/dimension/HPD_v02r02_stationinv_c20221129.csv')

# %%
df_st.dtypes
# Out:
# StnID                     object
# Lat                      float64
# Lon                      float64
# Elev                     float64
# State/Province            object
# Name                      object
# WMO_ID                   float64
# Sample_Interval (min)      int64
# UTC_Offset                 int64
# POR_Date_Range            object
# PCT_POR_Good              object
# Last_Half_POR             object
# PCT_Last_Half_Good        object
# Last_Qtr_POR              object
# PCT_Last_Qtr_Good         object
# dtype: object

# %%
df_st.columns = df_st.columns.str.lower()

# %%
df_st.rename(columns={'state/province': 'state',
                     'sample_interval (min)': 'sample_interval_min'}, inplace=True)

# %%
df_st.columns
# Out:
# Index(['stnid', 'lat', 'lon', 'elev', 'state', 'name', 'wmo_id',
#        'sample_interval_min', 'utc_offset', 'por_date_range', 'pct_por_good',
#        'last_half_por', 'pct_last_half_good', 'last_qtr_por',
#        'pct_last_qtr_good'],
#       dtype='object')

# %%
df_st
# Out:
#             stnid      lat       lon   elev state            name   wmo_id  \
# 0     USC00010008  31.5702  -85.2482  139.0    AL       ABBEVILLE      NaN
# 1     USC00010063  34.2110  -87.1784  239.6    AL         ADDISON      NaN
# 2     USC00010140  32.2322  -87.4104   53.3    AL         ALBERTA      NaN
# 3     USC00010252  31.3071  -86.5226   76.2    AL   ANDALUSIA 3 W      NaN
# 4     USC00010369  33.2941  -85.7788  311.5    AL   ASHLAND 3 ENE      NaN
# ...           ...      ...       ...    ...   ...             ...      ...
# 2003  AQC00914594 -14.3333 -170.7667   42.4    AS        MALAELOA      NaN
# 2004  USC00914670  13.4619  144.6894    3.0    GU            PITI      NaN
# 2005  CQC00914801  14.1717  145.2428  179.2    MP    ROTA AIRPORT  91221.0
# 2006  CQC00914855  15.1167  145.7167   65.5    MP  SAIPAN INTL AP  91232.0
# 2007  AQC00914902 -14.2728 -170.6922   80.8    AS         VAIPITO      NaN
#
#       sample_interval_min  utc_offset     por_date_range pct_por_good  \
# 0                      15          -6  19480601-20180418        83.6%
# 1                      15          -6  19480601-20210606        85.8%
# 2                      15          -6  19630926-20211231        94.4%
# 3                      15          -6  19800301-20180205        89.1%
# 4                      15          -6  19480601-20130804        84.6%
# ...                   ...         ...                ...          ...
# 2003                   15         -11  20190929-20210102        27.9%
# 2004                   15          10  19780701-20210205        71.7%
# 2005                   15          10  19820601-20210209        61.1%
# 2006                   15          10  19790901-20210201        68.2%
# 2007                   15         -11  20200406-20210103        73.6%
#
#           last_half_por pct_last_half_good       last_qtr_por  \
# 0     19830510-20180418              70.2%  20001028-20180418
# 1     19841203-20210606              83.2%  20030306-20210606
# 2     19921112-20211231              92.0%  20070607-20211231
# 3     19990217-20180205              92.3%  20080812-20180205
# 4     19810101-20130804              81.4%  19970418-20130804
# ...                 ...                ...                ...
# 2003  20200516-20210102              55.2%  20200908-20210102
# 2004  19991019-20210205              65.6%  20100613-20210205
# 2005  20011005-20210209              46.0%  20110608-20210209
# 2006  20000517-20210201              51.6%  20100924-20210201
# 2007  20200820-20210103              80.3%  20201027-20210103
#
#      pct_last_qtr_good
# 0                65.8%
# 1                74.6%
# 2                89.7%
# 3                97.5%
# 4                70.7%
# ...                ...
# 2003             38.5%
# 2004             72.4%
# 2005             48.9%
# 2006             56.5%
# 2007             84.1%
#
# [2008 rows x 15 columns]

# %%
df_st.to_csv('../data/out/dimension/dim_station.csv', index=False)

# %%
print(pd.io.sql.get_schema(df_st, 'dim_station', con=engine))
# Out:
# CREATE TABLE dim_station (
# 	stnid TEXT,
# 	lat FLOAT(53),
# 	lon FLOAT(53),
# 	elev FLOAT(53),
# 	state TEXT,
# 	name TEXT,
# 	wmo_id FLOAT(53),
# 	sample_interval_min BIGINT,
# 	utc_offset BIGINT,
# 	por_date_range TEXT,
# 	pct_por_good TEXT,
# 	last_half_por TEXT,
# 	pct_last_half_good TEXT,
# 	last_qtr_por TEXT,
# 	pct_last_qtr_good TEXT
# )

# %%
print(pd.io.sql.get_schema(df_st, 'station'))
# Out:
# CREATE TABLE "station" (
# "StnID" TEXT,
#   "Lat" REAL,
#   "Lon" REAL,
#   "Elev" REAL,
#   "State/Province" TEXT,
#   "Name" TEXT,
#   "WMO_ID" REAL,
#   "Sample_Interval (min)" INTEGER,
#   "UTC_Offset" INTEGER,
#   "POR_Date_Range" TEXT,
#   "PCT_POR_Good" TEXT,
#   "Last_Half_POR" TEXT,
#   "PCT_Last_Half_Good" TEXT,
#   "Last_Qtr_POR" TEXT,
#   "PCT_Last_Qtr_Good" TEXT
# )

# %% [markdown]
# ## State

# %%
df_s = pd.read_csv('../data/raw/dimension/hpd_states.txt', names=['state'])

# %%
df_s[['state_abbr','state_name']] = df_s.state.str.split(' ', n=1, expand=True)

# %%
df_s
# Out:
#                           state state_abbr                state_name
# 0                     AK ALASKA         AK                    ALASKA
# 1                   AL ALABAMA          AL                  ALABAMA
# 2                   AR ARKANSAS         AR                  ARKANSAS
# 3                    AZ ARIZONA         AZ                   ARIZONA
# 4                 CA CALIFORNIA         CA                CALIFORNIA
# 5                   CO COLORADO         CO                  COLORADO
# 6                CT CONNECTICUT         CT               CONNECTICUT
# 7                   DE DELAWARE         DE                  DELAWARE
# 8                    FL FLORIDA         FL                   FLORIDA
# 9                    GA GEORGIA         GA                   GEORGIA
# 10                      GU GUAM         GU                      GUAM
# 11                    HI HAWAII         HI                    HAWAII
# 12                      IA IOWA         IA                      IOWA
# 13                     ID IDAHO         ID                     IDAHO
# 14                  IL ILLINOIS         IL                  ILLINOIS
# 15                   IN INDIANA         IN                   INDIANA
# 16                    KS KANSAS         KS                    KANSAS
# 17                  KY KENTUCKY         KY                  KENTUCKY
# 18                 LA LOUISIANA         LA                 LOUISIANA
# 19                  MD MARYLAND         MD                  MARYLAND
# 20                     ME MAINE         ME                     MAINE
# 21                  MI MICHIGAN         MI                  MICHIGAN
# 22                 MN MINNESOTA         MN                 MINNESOTA
# 23                  MO MISSOURI         MO                  MISSOURI
# 24  MP NORTHERN MARIANA ISLANDS         MP  NORTHERN MARIANA ISLANDS
# 25               MS MISSISSIPPI         MS               MISSISSIPPI
# 26                   MT MONTANA         MT                   MONTANA
# 27            NC NORTH CAROLINA         NC            NORTH CAROLINA
# 28              ND NORTH DAKOTA         ND              NORTH DAKOTA
# 29                  NE NEBRASKA         NE                  NEBRASKA
# 30             NH NEW HAMPSHIRE         NH             NEW HAMPSHIRE
# 31                NJ NEW JERSEY         NJ                NEW JERSEY
# 32                NM NEW MEXICO         NM                NEW MEXICO
# 33                    NV NEVADA         NV                    NEVADA
# 34                  NY NEW YORK         NY                  NEW YORK
# 35                      OH OHIO         OH                      OHIO
# 36                  OK OKLAHOMA         OK                  OKLAHOMA
# 37                    OR OREGON         OR                    OREGON
# 38              PA PENNSYLVANIA         PA              PENNSYLVANIA
# 39               PR PUERTO RICO         PR               PUERTO RICO
# 40            SC SOUTH CAROLINA         SC            SOUTH CAROLINA
# 41              SD SOUTH DAKOTA         SD              SOUTH DAKOTA
# 42                 TN TENNESSEE         TN                 TENNESSEE
# 43                     TX TEXAS         TX                     TEXAS
# 44                      UT UTAH         UT                      UTAH
# 45                  VA VIRGINIA         VA                  VIRGINIA
# 46            VI VIRGIN ISLANDS         VI            VIRGIN ISLANDS
# 47                   VT VERMONT         VT                   VERMONT
# 48                WA WASHINGTON         WA                WASHINGTON
# 49                 WI WISCONSIN         WI                 WISCONSIN
# 50             WV WEST VIRGINIA         WV             WEST VIRGINIA
# 51                   WY WYOMING         WY                   WYOMING

# %%
df_s = df_s.drop(['state'], axis=1)

# %%
df_s
# Out:
#    state_abbr                state_name
# 0          AK                    ALASKA
# 1          AL                  ALABAMA
# 2          AR                  ARKANSAS
# 3          AZ                   ARIZONA
# 4          CA                CALIFORNIA
# 5          CO                  COLORADO
# 6          CT               CONNECTICUT
# 7          DE                  DELAWARE
# 8          FL                   FLORIDA
# 9          GA                   GEORGIA
# 10         GU                      GUAM
# 11         HI                    HAWAII
# 12         IA                      IOWA
# 13         ID                     IDAHO
# 14         IL                  ILLINOIS
# 15         IN                   INDIANA
# 16         KS                    KANSAS
# 17         KY                  KENTUCKY
# 18         LA                 LOUISIANA
# 19         MD                  MARYLAND
# 20         ME                     MAINE
# 21         MI                  MICHIGAN
# 22         MN                 MINNESOTA
# 23         MO                  MISSOURI
# 24         MP  NORTHERN MARIANA ISLANDS
# 25         MS               MISSISSIPPI
# 26         MT                   MONTANA
# 27         NC            NORTH CAROLINA
# 28         ND              NORTH DAKOTA
# 29         NE                  NEBRASKA
# 30         NH             NEW HAMPSHIRE
# 31         NJ                NEW JERSEY
# 32         NM                NEW MEXICO
# 33         NV                    NEVADA
# 34         NY                  NEW YORK
# 35         OH                      OHIO
# 36         OK                  OKLAHOMA
# 37         OR                    OREGON
# 38         PA              PENNSYLVANIA
# 39         PR               PUERTO RICO
# 40         SC            SOUTH CAROLINA
# 41         SD              SOUTH DAKOTA
# 42         TN                 TENNESSEE
# 43         TX                     TEXAS
# 44         UT                      UTAH
# 45         VA                  VIRGINIA
# 46         VI            VIRGIN ISLANDS
# 47         VT                   VERMONT
# 48         WA                WASHINGTON
# 49         WI                 WISCONSIN
# 50         WV             WEST VIRGINIA
# 51         WY                   WYOMING

# %%
df_s.to_csv('../data/out/dimension/dim_state.csv', index=False)

# %%
print(pd.io.sql.get_schema(df_s, 'dim_state', con=engine))
# Out:
# CREATE TABLE dim_state (
# 	state_abbr TEXT,
# 	state_name TEXT
# )
